# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.dates import date2num
from datetime import datetime
import matplotlib.dates as mdates

# Data for the Gantt chart
milestones = [
    'Initial and continuing IRB and ethics compliance (M6)',
    'Training of HE²AT Center on Research Project 2 methods (M6)',
    'Protocol paper published (M12)',
    'Data analysis plan written (M6)',
    'Data harmonization across DSI-Africa platform and other grantees (M12)',
    'Biomedical data recoded and merged into one database (M8)',
    'Database prepared for vulnerability-heat-health analysis (M12)',
    'Publications submitted on primary and secondary study outcomes',
    'Engagement with national government for EWS development',
    'Stakeholder engagements (community and health departments)',
    'Publications submitted on methodological aspects (M38)',
    'PhD enrolment (M7)',
    'Dissemination meetings and conferences',
    'Final report submitted (M58)'
]

start_dates = [
    '2021-09-01', '2021-09-01', '2022-06-01', '2022-06-01', '2023-06-01',
    '2024-02-01', '2023-06-01', '2024-11-01', '2024-10-01', '2024-10-01',
    '2025-04-01', '2024-07-01', '2025-01-01', '2026-06-01'
]

end_dates = [
    '2022-06-30', '2022-06-30', '2024-06-30', '2024-10-31', '2025-03-31',
    '2025-02-28', '2024-06-30', '2025-12-31', '2025-12-31', '2025-03-31',
    '2025-04-30', '2024-07-31', '2026-12-31', '2026-06-30'
]

# Convert dates to datetime format
start_dates = [datetime.strptime(date, '%Y-%m-%d') for date in start_dates]
end_dates = [datetime.strptime(date, '%Y-%m-%d') for date in end_dates]

# Create a DataFrame
chart_data = pd.DataFrame({'Milestone': milestones, 'Start': start_dates, 'End': end_dates})

# Plotting the Gantt Chart
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color='skyblue', edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Project')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.dates import date2num
from datetime import datetime
import matplotlib.dates as mdates

# Data for the Gantt chart
milestones = [
    'Initial and continuing IRB and ethics compliance (M6)',
    'Training of HE²AT Center on Research Project 2 methods (M6)',
    'Protocol paper published (M12)',
    'Data analysis plan written (M6)',
    'Data harmonization across DSI-Africa platform and other grantees (M12)',
    'Biomedical data recoded and merged into one database (M8)',
    'Database prepared for vulnerability-heat-health analysis (M12)',
    'Publications submitted on primary and secondary study outcomes',
    'Engagement with national government for EWS development',
    'Stakeholder engagements (community and health departments)',
    'Publications submitted on methodological aspects (M38)',
    'PhD enrolment (M7)',
    'Dissemination meetings and conferences',
    'Final report submitted (M58)'
]

start_dates = [
    '2021-09-01', '2021-09-01', '2022-06-01', '2022-06-01', '2023-06-01',
    '2024-02-01', '2023-06-01', '2024-11-01', '2024-10-01', '2024-10-01',
    '2025-04-01', '2024-07-01', '2025-01-01', '2026-06-01'
]

end_dates = [
    '2022-06-30', '2022-06-30', '2024-06-30', '2024-10-31', '2025-03-31',
    '2025-02-28', '2024-06-30', '2025-12-31', '2025-12-31', '2025-03-31',
    '2025-04-30', '2024-07-31', '2026-12-31', '2026-06-30'
]

statuses = [
    'Completed', 'Completed', 'Completed', 'Completed', 'In Progress',
    'In Progress', 'Completed', 'Not Started', 'In Progress', 'In Progress',
    'Not Started', 'Completed', 'Not Started', 'Not Started'
]

# Convert dates to datetime format
start_dates = [datetime.strptime(date, '%Y-%m-%d') for date in start_dates]
end_dates = [datetime.strptime(date, '%Y-%m-%d') for date in end_dates]

# Create a DataFrame
chart_data = pd.DataFrame({'Milestone': milestones, 'Start': start_dates, 'End': end_dates, 'Status': statuses})

# Plotting the Gantt Chart
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    if row['Status'] == 'Completed':
        color = 'green'
    elif row['Status'] == 'In Progress':
        color = 'orange'
    else:
        color = 'red'
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color=color, edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Project')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.dates import date2num
from datetime import datetime
import matplotlib.dates as mdates

# Data for the Gantt chart
milestones = [
    'Initial and continuing IRB and ethics compliance (M6)',
    'Training of HE²AT Center on Research Project 2 methods (M6)',
    'Protocol paper published (M12)',
    'Data analysis plan written (M6)',
    'Data harmonization across DSI-Africa platform and other grantees (M12)',
    'Biomedical data recoded and merged into one database (M8)',
    'Database prepared for vulnerability-heat-health analysis (M12)',
    'Publications submitted on primary and secondary study outcomes',
    'Engagement with national government for EWS development',
    'Stakeholder engagements (community and health departments)',
    'Publications submitted on methodological aspects (M38)',
    'PhD enrolment (M7)',
    'Dissemination meetings and conferences',
    'Final report submitted (M58)'
]

start_dates = [
    '2021-09-01', '2021-09-01', '2022-06-01', '2022-06-01', '2023-06-01',
    '2024-02-01', '2023-06-01', '2024-11-01', '2024-10-01', '2024-10-01',
    '2025-04-01', '2024-07-01', '2021-09-01', '2026-06-01'
]

end_dates = [
    '2022-06-30', '2022-06-30', '2024-06-30', '2024-10-31', '2025-03-31',
    '2025-02-28', '2024-06-30', '2025-12-31', '2025-12-31', '2025-03-31',
    '2025-04-30', '2024-07-31', '2026-06-30', '2026-06-30'
]

statuses = [
    'Completed', 'Completed', 'Completed', 'Completed', 'In Progress',
    'In Progress', 'Completed', 'In Progress', 'In Progress', 'In Progress',
    'Not Started', 'Completed', 'Not Started', 'Not Started'
]

# Convert dates to datetime format
start_dates = [datetime.strptime(date, '%Y-%m-%d') for date in start_dates]
end_dates = [datetime.strptime(date, '%Y-%m-%d') for date in end_dates]

# Create a DataFrame
chart_data = pd.DataFrame({'Milestone': milestones, 'Start': start_dates, 'End': end_dates, 'Status': statuses})

# Plotting the Gantt Chart
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    if row['Status'] == 'Completed':
        color = 'green'
    elif row['Status'] == 'In Progress':
        color = 'orange'
    else:
        color = 'red'
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color=color, edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Project')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting the Gantt Chart with specific color for "Dissemination meetings and conferences"
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    if row['Milestone'] == 'Dissemination meetings and conferences':
        color = 'orange'
    elif row['Status'] == 'Completed':
        color = 'green'
    elif row['Status'] == 'In Progress':
        color = 'orange'
    else:
        color = 'red'
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color=color, edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Research Project 2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting the Gantt Chart with specific color for "Data analysis plan written (M6)"
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    if row['Milestone'] == 'Data analysis plan written (M6)':
        color = 'orange'
    elif row['Milestone'] == 'Dissemination meetings and conferences':
        color = 'orange'
    elif row['Status'] == 'Completed':
        color = 'green'
    elif row['Status'] == 'In Progress':
        color = 'orange'
    else:
        color = 'red'
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color=color, edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Project')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.dates import date2num
from datetime import datetime
import matplotlib.dates as mdates

# Data for the Gantt chart
milestones = [
    'Initial and continuing IRB and ethics compliance (M6)',
    'Training of HE²AT Center on Research Project 2 methods (M6)',
    'Protocol paper published (M12)',
    'Data analysis plan written (M6)',
    'Data harmonization across DSI-Africa platform and other grantees (M12)',
    'Biomedical data recoded and merged into one database (M8)',
    'Database prepared for vulnerability-heat-health analysis (M12)',
    'Publications submitted on primary and secondary study outcomes',
    'Engagement with national government for EWS development',
    'Stakeholder engagements (community and health departments)',
    'Publications submitted on methodological aspects (M38)',
    'PhD enrolment (M7)',
    'Dissemination meetings and conferences',
    'Final report submitted (M58)'
]

start_dates = [
    '2021-09-01', '2021-09-01', '2022-06-01', '2022-06-01', '2023-06-01',
    '2024-02-01', '2023-06-01', '2024-11-01', '2024-10-01', '2024-10-01',
    '2025-04-01', '2024-07-01', '2021-09-01', '2026-06-01'
]

end_dates = [
    '2022-06-30', '2022-06-30', '2024-06-30', '2024-10-31', '2025-03-31',
    '2025-02-28', '2024-06-30', '2025-12-31', '2025-12-31', '2025-03-31',
    '2025-04-30', '2024-07-31', '2026-06-30', '2026-06-30'
]

statuses = [
    'Completed', 'Completed', 'Completed', 'Completed', 'In Progress',
    'In Progress', 'Completed', 'In Progress', 'In Progress', 'In Progress',
    'Not Started', 'Completed', 'Not Started', 'Not Started'
]

# Convert dates to datetime format
start_dates = [datetime.strptime(date, '%Y-%m-%d') for date in start_dates]
end_dates = [datetime.strptime(date, '%Y-%m-%d') for date in end_dates]

# Create a DataFrame
chart_data = pd.DataFrame({'Milestone': milestones, 'Start': start_dates, 'End': end_dates, 'Status': statuses})

# Plotting the Gantt Chart
fig, ax = plt.subplots(figsize=(10, 8))
for i, row in chart_data.iterrows():
    if row['Status'] == 'Completed':
        color = 'green'
    elif row['Status'] == 'In Progress':
        color = 'orange'
    else:
        color = 'red'
    ax.barh(row['Milestone'], date2num(row['End']) - date2num(row['Start']), left=date2num(row['Start']), color=color, edgecolor='black')

# Formatting
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xlabel('Timeline')
plt.ylabel('Milestones')
plt.title('Updated Gantt Chart for HE²AT Center Project')
plt.xticks(rotation=45)
plt.tight_layout()

# Adding a key to represent milestone status
plt.figtext(0.9, 0.2, 'Key:', fontsize=10, fontweight='bold')
plt.figtext(0.9, 0.15, 'Green: Completed', fontsize=8)
plt.figtext(0.9, 0.1, 'Orange: In Progress', fontsize=8)
plt.figtext(0.9, 0.05, 'Red: Not Started', fontsize=8)

plt.show()

# %%
import matplotlib.patches as mpatches

# Define custom legend
completed_patch = mpatches.Patch(color='green', label='Completed')
in_progress_patch = mpatches.Patch(color='orange', label='In Progress')
not_started_patch = mpatches.Patch(color='red', label='Not Started')

# Add legend to the plot
ax.legend(handles=[completed_patch, in_progress_patch, not_started_patch], loc='upper right')

# Show the plot with the legend
plt.show()
